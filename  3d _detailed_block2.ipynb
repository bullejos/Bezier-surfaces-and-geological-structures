# %%
import functions
from functions import *
DATADIR='data/' # Directory with the data
CSV='data/csv/'
FIGURESDIR='figures/' # Figures produced
import topo
from topo import *

# %% [markdown]
# # 3D Detailed block 2. Marinas Height

# %% [markdown]
# The region

# %%
puntosx_b2=[630973,631434,631981,631560]
puntosy_b2=[4212829, 4212180,4212624,4213252]
puntos_b2=[(puntosx_b2[i],puntosy_b2[i]) for i in range(len(puntosx_b2))]
import inferiores_v2
from inferiores_v2 import *
from sector1 import *

# %% [markdown]
# # In surface

# %%
r2grd=pd.read_csv(DATADIR+'blocks/r2grd.csv')
p1_b2=pd.read_csv(DATADIR+'blocks/r2p1.csv')
p2_b2=pd.read_csv(DATADIR+'blocks/r2p2.csv')
p3_b2=pd.read_csv(DATADIR+'blocks/r2p3.csv')
p4_b2=pd.read_csv(DATADIR+'blocks/r2p4.csv')
E21=surface2nearpol2(r2grd,300,'linear',p1_b2,puntos_b2,20,12)

E1=surface2nearpol2(r2grd,300,'linear',p2_b2,puntos_b2,10,12)

E22=surface2nearpol2(r2grd,300,'linear',p3_b2,puntos_b2,20,12)
C=surface2nearpol2(r2grd,300,'linear',p4_b2,puntos_b2,1,12)
r2t1=pd.read_csv(DATADIR+'blocks/r2t1.csv')
xr2t1=r2t1['X']
yr2t1=r2t1['Y']
zr2t1=r2t1['SAMPLE_1']

r2t2=pd.read_csv(DATADIR+'blocks/r2t2.csv')
xr2t2=r2t2['X']
yr2t2=r2t2['Y']
zr2t2=r2t2['SAMPLE_1']

r2t3=pd.read_csv(DATADIR+'blocks/r2t3.csv')
xr2t3=r2t3['X']
yr2t3=r2t3['Y']
zr2t3=r2t3['SAMPLE_1']

co3=pd.read_csv(DATADIR+'conformity/co3.csv')
xco3=[co3['X'][i] for i in range(228,407,2)]+[co3['X'][i] for i in range(466,619,2)]
yco3=[co3['Y'][i] for i in range(228,407,2)]+[co3['Y'][i] for i in range(466,619,2)]
zco3=[co3['SAMPLE_1'][i]+15 for i in range(228,407,2)]+[co3['SAMPLE_1'][i]+15 for i in range(466,619,2)]

r2t1_dat= go.Scatter3d(mode='markers',
              x=xco3,y=yco3,z=zco3,
              name='Conformity',
              legendgroup='trc',
              showlegend=True,
              marker=dict(
              color='black',
              size=2.5))


r2t3_dat=contact_dat2(xr2t3,yr2t3,zr2t3,15,"lines",'Thrust','blue','thr',True,None,10)
r2t_dat=[r2t1_dat,r2t3_dat]
thx,thy,thz=bsr(listado1,puntos_b2)
for i in range(len(thz)-100):
               thz[i]=thz[i]-10
sth=surface2([thx,thy,thz],100,'linear')

# %% [markdown]
# # In depth

# %%
from sector2 import *

# %%
# Cretaceus

xlC12,ylC12,zlC12=bsr(lC12,puntos_b2)
xlC1201,ylC1201,zlC1201=bs2r(lC1201,puntos_b2)
xlC121,ylC121,zlC121=bsr(lC121,puntos_b2)
xlC12102,ylC12102,zlC12102=bs2r(lC12102,puntos_b2)
xlC122,ylC122,zlC122=bsr(lC122,puntos_b2)

slC12=surface2([xlC12+xlC1201+xlC121+xlC12102+xlC122,ylC12+ylC1201+ylC121+ylC12102+ylC122,
                zlC12+zlC1201+zlC121+zlC12102+zlC122],100,'linear')

trace1=go.Surface(x=slC12[3],y=slC12[4],z=slC12[5],
                   colorscale=verde_c,
                   opacity = 1,
                   name='C12',
                   legendgroup='c',
                   showlegend=False,
                   showscale=False)

#Paleocene
        
xlC22,ylC22,zlC22=bsr(lC22,puntos_b2)
xlC2201,ylC2201,zlC2201=bs2r(lC2201,puntos_b2)
xlC221,ylC221,zlC221=bsr(lC221,puntos_b2)
xlC22102,ylC22102,zlC22102=bs2r(lC22102,puntos_b2)
xlC222,ylC222,zlC222=bsr(lC222,puntos_b2)
slC22=surface2([xlC22+xlC2201+xlC221+xlC22102+xlC222,ylC22+ylC2201+ylC221+ylC22102+ylC222,
                zlC22+zlC2201+zlC221+zlC22102+zlC222],100,'linear')
trace2=go.Surface(x=slC22[3],y=slC22[4],z=slC22[5],
                   colorscale=violeta,
                   opacity = 1,
                   name='Paleocene',
                   legendgroup='P',
                   showlegend=True,
                   showscale=False)

# Eocene1

xlP2,ylP2,zlP2=bsr(lP2,puntos_b2)
xlP201,ylP201,zlP201=bs2r(lP201,puntos_b2)
xlP21,ylP21,zlP21=bsr(lP21,puntos_b2)
xlP2102,ylP2102,zlP2102r=bs2r(lP2102,puntos_b2)
xlP22,ylP22,zlP22=bsr(lP22,puntos_b2)
slP=surface2([xlP2+xlP201+xlP21+xlP22,ylP2+ylP201+ylP21+ylP22,
              zlP2+zlP201+zlP21+zlP22],100,'linear')

trace3=go.Surface(x=slP[3],y=slP[4],z=slP[5],
                   colorscale=naranja,
                   opacity = 1,
                   name='P',
                   legendgroup='e1',
                   showlegend=False,
                   showscale=False)

# %%
from sector3 import *

# %%
# Cretaceus

xC1_3,yC1_3,zC1_3=bezierr(ControlC1_3.loc[:19],5,puntos_b2)
xC1_3c,yC1_3c,zC1_3c=bezierr(ControlC1_3.loc[15:],5,puntos_b2)
sC1_3=surface2([xC1_3+xC1_3c,yC1_3+yC1_3c,zC1_3+zC1_3c],100,'linear')

trace4=go.Surface(x=sC1_3[3],y=sC1_3[4],z=sC1_3[5],
                    colorscale=verde_c,
                    opacity = 1,
                    name='C1',
                    legendgroup='c',
                    showlegend=False,
                    showscale=False)

# %%
E1=surface2nearpol2(r2grd,300,'linear',p2_b2,puntos_b2,10,12)

# %% [markdown]
# Geological simbols

# %%
trian=pd.read_csv(DATADIR+'blocks/r2trian.csv')
trian_dat=triangulo(trian,'thr',15)
dirf1=pd.read_csv(DATADIR+'csv/dirf1.csv')
#zz=[max(dirf1['SAMPLE_1']) for i in range(3)]
zz=[x+10 for x in dirf1['SAMPLE_1']]
dirf2=pd.read_csv(DATADIR+'csv/dirf2.csv')
#zz2=[max(dirf2['SAMPLE_1']) for i in range(3)]
zz2=[x+10 for x in dirf2['SAMPLE_1']]

flomo1_dat=falla(flomo1up,flomo1dwn,'#404040','Faults',1,'fallas','y',False)
data_fallas=flomo1_dat+flomo2_dat+fcastillo1_dat+fcastillo2_dat

sinr21=pd.read_csv(DATADIR+'blocks/sinr21.csv')
xsinr21,ysinr21,zsinr21=bzcurv(sinr21,500,10)
sinr22=pd.read_csv(DATADIR+'blocks/sinr22.csv')
xsinr22,ysinr22,zsinr22=bzcurv(sinr22,500,10)

sin_dat=[go.Scatter3d(mode='lines',
        x=xsinr21[0],y=ysinr21[0],z=zsinr21[0],
        name='Overturned anticline0',
        legendgroup='anty',
        showlegend=False,
        line=dict(
            color='black',
            width=4)),
        go.Scatter3d(mode='lines',
        x=xsinr22[0],y=ysinr22[0],z=zsinr22[0],
        name='Overturned anticline1',
        legendgroup='anty',
        showlegend=False,
        line=dict(
            color='black',
            width=4))]
asinr21=pd.read_csv(DATADIR+'blocks/asinr21.csv')
xasinr21,yasinr21,zasinr21=bzcurv(asinr21,430,10)

asin_dat=[go.Scatter3d(mode='lines',
        x=xasinr21[0],y=yasinr21[0],z=zasinr21[0],
        name='Overturned syncline2',
        legendgroup='syn',
        showlegend=False,
        line=dict(
            color='black',
            width=4))]

t1s1=pd.read_csv(DATADIR+'blocks/tr21.csv')
t1s1_dat=sinsymb(t1s1,500,10,'anty',False,4,'Overturned anticline3')
t1s2=pd.read_csv(DATADIR+'blocks/tr22.csv')
t1s2_dat=sinsymb(t1s2,500,10,'anty',False,4,'anticline4')

ts_dat=t1s1_dat+t1s2_dat#+t3s1_dat+t4s1_dat
at21=pd.read_csv(DATADIR+'blocks/atr21.csv')


at21_dat=asinsymb(at21,400,10,'syn',True,4,'Overturned Syncline')
at_dat=at21_dat+[go.Scatter3d(x=[at21['X'][0]],y=[at21['Y'][0]],z=[1000],
                              mode='markers',
                              name='Overturned Anticline',
                              legendgroup='anty',
                              showlegend=True,
                              marker = dict(size = 10,
                                            color ='black',
                                            opacity = 1,
                                            symbol='diamond'))]

# %% [markdown]
# # Eocene 2

# %%
ControlE1_2_f_r=pd.read_csv(DATADIR+'/control/E1_2_f_r2.csv')
xEo2_0,yEo2_0,zEo2_0=bezier(ControlE1_2_f_r,3)

trace5_0=go.Surface(x=xEo2_0,y=yEo2_0,z=zEo2_0,
                           colorscale=pink,
                           opacity = 1,
                           name='Eocene 2 profundo',
                           legendgroup='e2',
                           showlegend=False,
                           showscale=False)

# %%
ControlE1_21_r=pd.read_csv(DATADIR+'/control/E1_21_2_r.csv')
xEo21,yEo21,zEo21=bezier(ControlE1_21_r,3)

trace5_1=go.Surface(  x=xEo21,y=yEo21,z=zEo21,
                           colorscale=pink,
                           opacity = 1,
                           name='Eocene 2',
                           legendgroup='e2',
                           showlegend=False,
                           showscale=False)

# %%
# Eocene 2
ControlE1_22f_r=pd.read_csv(DATADIR+'/control/E1_2_22f2r.csv')
xEo22f,yEo22f,zEo22f=bezier(ControlE1_22f_r,3)

trace5_2f=go.Surface(  x=xEo22f,y=yEo22f,z=zEo22f,
                           colorscale=pink,
                           opacity = 1,
                           name='Eocene 2',
                           legendgroup='e2',
                           showlegend=False,
                           showscale=False)

# %%
ControlE1_2m_r=pd.read_csv(DATADIR+'/control/E1_2_22mr.csv')
xEo22m,yEo22m,zEo22m=bezier(ControlE1_2m_r,3)

trace5_2m=go.Surface(  x=xEo22m,y=yEo22m,z=zEo22m,
                           colorscale=pink,
                           opacity = 1,
                           name='Eocene 2',
                           legendgroup='e2',
                           showlegend=False,
                           showscale=False)

# %%
fig=go.Figure(r2t_dat+data_fallas+tracks_fallas_data+trian_dat+sin_dat+asin_dat+ts_dat+at_dat)

fig.add_trace(go.Scatter3d(x=dirf1['X'],y=dirf1['Y'],z=zz,
                           mode='lines',
                           name='Strike-slip fault',
                           legendgroup='fallas',
                           showlegend=True,
                           line=dict(color='black', width=5)))
fig.add_trace(go.Scatter3d(x=dirf2['X'],y=dirf2['Y'],z=zz2,
                           mode='lines',
                           legendgroup='fallas',
                           showlegend=False,
                           line=dict(color='black', width=5)))


fig.add_trace(go.Surface(  x=sth[3],y=sth[4],z=sth[5],
                           colorscale=azul,
                           opacity = 1,
                           name='Thrust',
                           legendgroup='thr',
                           showlegend=False,
                           showscale=False))

fig.add_trace(go.Surface(  x=E21[3],y=E21[4],z=E21[5],
                           colorscale=pink,
                           opacity = 1,
                           name='Eocene 2',
                           legendgroup='e2',
                           showlegend=True,
                           showscale=False))

fig.add_trace(go.Surface(  x=E22[3],y=E22[4],z=E22[5],
                           colorscale=pink,
                           opacity = 1,
                           name='Eocene 2',
                           legendgroup='e2',
                           showlegend=False,
                           showscale=False))

fig.add_trace(go.Surface(  x=E1[3],y=E1[4],z=E1[5],
                           colorscale=naranja,
                           opacity = 1,
                           name='Eocene 1',
                           legendgroup='e1',
                           showlegend=True,
                           showscale=False) )

fig.add_trace(trace1)
fig.add_trace(trace2)

fig.add_trace(go.Surface(  x=C[3],y=C[4],z=C[5],
                           colorscale=verde_c,
                           opacity = 1,
                           name='Cretaceus',
                           legendgroup='c',
                           showlegend=True,
                           showscale=False))


fig.add_trace(trace3)
fig.add_trace(trace4)
fig.add_trace(trace5_0)
fig.add_trace(trace5_1)
fig.add_trace(trace5_2f)
fig.add_trace(trace5_2m)



camera = dict(up=dict(x=0, y=0, z=1),
              center=dict(x=0, y=0, z=0),
               eye=dict(x=-1.25, y=-1.25, z=1.25) )

fig.update_layout( title="Marinas Height (Box 2)",
                  #paper_bgcolor = 'black',
                 scene = dict(
                     xaxis=dict(title='UTM_X', 
                                tickfont = dict(size = 10,color = 'black'),
                                title_font_size=10,
                                titlefont_color='black', 
                                range=[min(puntosx_b2),max(puntosx_b2)-10],
                                backgroundcolor='white',
                                color='black',
                                gridcolor='gray'),
                     yaxis=dict(title='UTM_Y',
                                tickfont = dict(size = 10,color = 'black'),
                                title_font_size=10,
                                titlefont_color='black', 
                                range=[min(puntosy_b2),max(puntosy_b2)],  
                                backgroundcolor='white',
                                color='black',
                                gridcolor='gray'),
                      zaxis=dict(nticks=4,
                                tickfont = dict(size = 10,color = 'black'),
                                title='Elevation', 
                                title_font_size=10,
                                titlefont_color='black', 
                                range=[0,600],
                                backgroundcolor='white',
                                color='black', 
                                gridcolor='gray'),
                     aspectratio=dict(x=2, y=2, z=0.5)),
                     #aspectmode='data'),
                     scene_camera= camera,
                     legend_itemsizing='constant'
                 ) 
              

fig.show()
go_offline.plot(fig,filename=FIGURESDIR+'Box2_3D_model.html',validate=True, auto_open=False)

# %%
fig=go.Figure(r2t_dat+data_fallas+tracks_fallas_data+trian_dat+sin_dat+asin_dat+ts_dat+at_dat)

fig.add_trace(go.Scatter3d(x=dirf1['X'],y=dirf1['Y'],z=zz,
                           mode='lines',
                           name='Strike-slip fault',
                           legendgroup='fallas',
                           showlegend=True,
                           line=dict(color='black', width=5)))
fig.add_trace(go.Scatter3d(x=dirf2['X'],y=dirf2['Y'],z=zz2,
                           mode='lines',
                           legendgroup='fallas',
                           showlegend=False,
                           line=dict(color='black', width=5)))


fig.add_trace(go.Surface(  x=sth[3],y=sth[4],z=sth[5],
                           colorscale=azul,
                           opacity = 1,
                           name='Thrust',
                           legendgroup='thr',
                           showlegend=False,
                           showscale=False))

fig.add_trace(go.Surface(  x=E21[3],y=E21[4],z=E21[5],
                           colorscale=pink,
                           opacity = 1,
                           name='Eocene 2',
                           legendgroup='e2',
                           showlegend=True,
                           showscale=False))

fig.add_trace(go.Surface(  x=E22[3],y=E22[4],z=E22[5],
                           colorscale=pink,
                           opacity = 1,
                           name='Eocene 2',
                           legendgroup='e2',
                           showlegend=False,
                           showscale=False))

fig.add_trace(go.Surface(  x=E1[3],y=E1[4],z=E1[5],
                           colorscale=naranja,
                           opacity = 1,
                           name='Eocene 1',
                           legendgroup='e1',
                           showlegend=True,
                           showscale=False) )

fig.add_trace(trace1)
fig.add_trace(trace2)

fig.add_trace(go.Surface(  x=C[3],y=C[4],z=C[5],
                           colorscale=verde_c,
                           opacity = 1,
                           name='Cretaceus',
                           legendgroup='c',
                           showlegend=True,
                           showscale=False))


fig.add_trace(trace3)
fig.add_trace(trace4)
fig.add_trace(trace5_0)
fig.add_trace(trace5_1)
fig.add_trace(trace5_2f)
fig.add_trace(trace5_2m)




camera = dict(up=dict(x=0, y=0, z=1),
              center=dict(x=0, y=0, z=0),
               eye=dict(x=-1.25, y=-1.25, z=1.25) )

fig.update_layout( title="Marinas Height (Box 2)",
                  #paper_bgcolor = 'black',
                 scene = dict(
                     xaxis=dict(title='', 
                                tickfont = dict(size = 10,color = 'black'),
                                title_font_size=10,
                                titlefont_color='black', 
                                range=[min(puntosx_b2),max(puntosx_b2)-10],
                                backgroundcolor='white',
                                color='black',
                                gridcolor='gray',
                                showgrid = False,
                                showticklabels = False),
                     yaxis=dict(title='',
                                tickfont = dict(size = 10,color = 'black'),
                                title_font_size=10,
                                titlefont_color='black', 
                                range=[min(puntosy_b2),max(puntosy_b2)],  
                                backgroundcolor='white',
                                color='black',
                                gridcolor='gray',
                                showgrid = False,
                                showticklabels = False,
                                ),
                      zaxis=dict(nticks=4,
                                tickfont = dict(size = 10,color = 'black'),
                                title='', 
                                title_font_size=10,
                                titlefont_color='black', 
                                range=[0,600],
                                backgroundcolor='white',
                                color='black', 
                                gridcolor='gray',
                                showgrid = False,
                                showticklabels = False),
                     aspectratio=dict(x=2, y=2, z=0.5)),
                     #aspectmode='data'),
                     scene_camera= camera,
                     legend_itemsizing='constant'
                 ) 
              

fig.show()
go_offline.plot(fig,filename=FIGURESDIR+'Box1_3D_model_w.html',validate=True, auto_open=False)
